# %% [markdown]
# ## OpenCV

# %%
import cv2
image=cv2.imread('mp.jpg')
print(image)
# Out:
# [[[ 80 118 182]
#   [ 80 118 182]
#   [ 80 118 182]
#   ...
#   [101 128 178]
#   [ 32  58 104]
#   [ 26  50  96]]
#
#  [[ 81 119 183]
#   [ 81 119 183]
#   [ 81 119 183]
#   ...
#   [ 95 122 172]
#   [ 27  53  99]
#   [ 21  45  91]]
#
#  [[ 83 121 185]
#   [ 82 120 184]
#   [ 82 120 184]
#   ...
#   [ 94 121 171]
#   [ 28  54 101]
#   [ 23  47  93]]
#
#  ...
#
#  [[151 187 223]
#   [151 187 223]
#   [152 188 224]
#   ...
#   [150 169 202]
#   [ 63  81 110]
#   [ 55  71 100]]
#
#  [[155 188 221]
#   [155 188 221]
#   [156 189 222]
#   ...
#   [152 170 201]
#   [ 65  82 109]
#   [ 58  72 100]]
#
#  [[156 187 220]
#   [158 189 222]
#   [158 189 222]
#   ...
#   [154 171 198]
#   [ 66  81 107]
#   [ 59  73  96]]]

# %%
print (image.shape)
# Out:
# (673, 1200, 3)

# %%
import matplotlib.pyplot as plt
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("Sherlock & Moriarty")
plt.show()
